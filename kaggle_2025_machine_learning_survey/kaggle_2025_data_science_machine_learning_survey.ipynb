# %%
import pandas as pd

free_from = pd.read_csv("freeFormResponses.csv")
# Out:
# /tmp/ipykernel_1073633/1730731019.py:3: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   free_from = pd.read_csv("freeFormResponses.csv")

# %%
free_from.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 35 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Q11_OTHER_TEXT   545 non-null    object
#  1   Q12_OTHER_TEXT   1710 non-null   object
#  2   Q12_Part_1_TEXT  3927 non-null   object
#  3   Q12_Part_2_TEXT  1448 non-null   object
#  4   Q12_Part_3_TEXT  1134 non-null   object
#  5   Q12_Part_4_TEXT  9553 non-null   object
#  6   Q12_Part_5_TEXT  1353 non-null   object
#  7   Q13_OTHER_TEXT   1193 non-null   object
#  8   Q14_OTHER_TEXT   499 non-null    object
#  9   Q15_OTHER_TEXT   575 non-null    object
#  10  Q16_OTHER_TEXT   597 non-null    object
#  11  Q17_OTHER_TEXT   114 non-null    object
#  12  Q18_OTHER_TEXT   162 non-null    object
#  13  Q19_OTHER_TEXT   449 non-null    object
#  14  Q1_OTHER_TEXT    80 non-null     object
#  15  Q20_OTHER_TEXT   94 non-null     object
# ...

# %%
free_from
# Out:
#                                           Q11_OTHER_TEXT  \
# 0      Select any activities that make up an importan...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 23855                                                NaN
# 23856                                                NaN
# 23857                                                NaN
# 23858                                                NaN
# 23859                                                NaN
#
#                                           Q12_OTHER_TEXT  \
# 0      What is the primary tool that you use at work ...
# 1                                                    NaN
# 2                                                    NaN
# ...

# %%
multiple_choice = pd.read_csv("multipleChoiceResponses.csv")
# Out:
# /tmp/ipykernel_1073633/457878530.py:1: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,42,44,54,56,64,81,83,85,87,105,107,109,121,123,125,148,150,157,172,174,192,194,210,218,219,221,223,246,247,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,302,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.
#   multiple_choice = pd.read_csv("multipleChoiceResponses.csv")

# %%
multiple_choice
# Out:
#       Time from Start to Finish (seconds)  \
# 0                   Duration (in seconds)
# 1                                     710
# 2                                     434
# 3                                     718
# 4                                     621
# ...                                   ...
# 23855                                 575
# 23856                                 131
# 23857                                 370
# 23858                                  36
# 23859                                 502
#
#                                            Q1  \
# 0      What is your gender? - Selected Choice
# 1                                      Female
# 2                                        Male
# 3                                      Female
# 4                                        Male
# ...                                       ...
# 23855                                    Male
# 23856                                  Female
# ...

# %%
multiple_choice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Columns: 395 entries, Time from Start to Finish (seconds) to Q50_OTHER_TEXT
# dtypes: object(395)
# memory usage: 71.9+ MB

# %%
multiple_choice.head()
# Out:
#   Time from Start to Finish (seconds)                                      Q1  \
# 0               Duration (in seconds)  What is your gender? - Selected Choice
# 1                                 710                                  Female
# 2                                 434                                    Male
# 3                                 718                                  Female
# 4                                 621                                    Male
#
#                                        Q1_OTHER_TEXT  \
# 0  What is your gender? - Prefer to self-describe...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
#                             Q2                                         Q3  \
# 0  What is your age (# years)?  In which country do you currently reside?
# ...

# %%
df = pd.DataFrame(multiple_choice, columns=[
    "Q19_Part_1", "Q19_Part_2", "Q19_Part_3", "Q19_Part_4",
    "Q19_Part_5", "Q19_Part_6", "Q19_Part_7", "Q19_Part_8", "Q19_Part_9", "Q19_Part_10",
    "Q19_Part_11", "Q19_Part_12", "Q19_Part_13", "Q19_Part_14", "Q19_Part_15", "Q19_Part_16",
    "Q19_Part_17"
])

# %%
df
# Out:
#                                               Q19_Part_1  \
# 0      What machine learning frameworks have you used...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                           Scikit-Learn
# ...                                                  ...
# 23855                                       Scikit-Learn
# 23856                                                NaN
# 23857                                                NaN
# 23858                                                NaN
# 23859                                                NaN
#
#                                               Q19_Part_2  \
# 0      What machine learning frameworks have you used...
# 1                                                    NaN
# 2                                                    NaN
# ...

# %%
q19_cols = [c for c in df.columns if c.startswith("Q19_Part_")]

# %%
df_long = df[q19_cols].melt(
    var_name="Part",         
    value_name="Framework"
)

# %%
df_long
# Out:
#                Part                                          Framework
# 0        Q19_Part_1  What machine learning frameworks have you used...
# 1        Q19_Part_1                                                NaN
# 2        Q19_Part_1                                                NaN
# 3        Q19_Part_1                                                NaN
# 4        Q19_Part_1                                       Scikit-Learn
# ...             ...                                                ...
# 405615  Q19_Part_17                                              Caffe
# 405616  Q19_Part_17                                                NaN
# 405617  Q19_Part_17                                                NaN
# 405618  Q19_Part_17                                                NaN
# 405619  Q19_Part_17                                                NaN
#
# [405620 rows x 2 columns]

# %%
df_long = df_long.dropna(subset=["Framework"])

# %%
counts = (
    df_long
    .groupby("Framework")
    .size()
    .sort_values(ascending=False)
    .reset_index(name="Count")
)

# %%
counts
# Out:
#                                             Framework  Count
# 0                                        Scikit-Learn  12249
# 1                                          TensorFlow   9981
# 2                                               Keras   8136
# 3                                        randomForest   5967
# 4                                             Xgboost   5571
# 5                                             PyTorch   3826
# 6                                               Caret   2220
# 7                                            lightgbm   2099
# 8                                         Spark MLlib   2055
# 9                                                 H20   1307
# 10                                              Caffe   1101
# 11                                             Fastai   1099
# 12                                           catboost   1037
# 13                                               CNTK    744
# ...
